# %% [markdown]
# Variabili e tipi di dato

# %%
a = 3 #Intera
x = 2.1 #Float //tramite un sistema floating point
s = "pippo" #Stringa //ammesso anche il singolo apice 'pippo'
b = True #Booleana

# %% [markdown]
# Funzione type per vedere il tipo di dato

# %%
a = 3
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# Stringhe

# %%
s1 = "Ciao"
s2 = ", come va"
s = s1 + s2

# %% [markdown]
# Stampare un valore

# %%
s = "Il valore di a =" +str(a)

# %% [markdown]
# f stringa permette di mantenere il tipo al dato stampato

# %%
s = f"Il valore di a = {a}"

# %%
pi = 3.141098765456789
s = "Il valore del pigreco è {pi:0.4f}" #con precisione 4 cifre

# %% [markdown]
# Variabile None

# %%
a = None #non ci sono valori assegnati a questa variabile
print(a is None) #ritorna true se a è vuota

# %% [markdown]
# Tipizzazione

# %% [markdown]
# Non sono obbligato ad inizializzare le variabili, ma serve per rendere noto il tipo della variabile

# %%
a : int = 3
#ma se faccio
a: int = "pippo"
#non produco errore

# %% [markdown]
# Array

# %% [markdown]
# Su pyton ci sono due tipi, liste e tuple. La differenza è che la tupla non non puà essere modificata, ma puù essere mista

# %%
a = [1, 5, 3] #interi
b = ["c", "i", "a", "o"] #caratteri
c = ["c", 3, True] #mista

t = (3, "c", [1,2,3]) #tupla mista

#tipizzazione
a: list[int] = [1,3,4]

# %% [markdown]
# Posso ideintificare il tipo di dato dentro una lista nel modo seguente

# %%
l = [1,3,4]

print(f"L'elemento di posto 2 nella lista è: {l[2]}")
# Out:
# L'elemento di posto 2 nella lista è: 4

# %% [markdown]
# Slicing

# %% [markdown]
# Posso estrarre elementi da una lista senza un ciclo tramite lo slicing

# %%
a: list[int] = [0,1,2,3,4,5,6,7]
#estraggo i pari
pari = a[0:7:2] #inizio da 0, finisco a 7 escluso, con passo 2, se il passo 
#non viene inserito in automatico mettiamo 1

# %% [markdown]
# se voglio andare fino alla fine dell'array senza sapere la sua dimensione mi basta inserire -1 come secondo argomento dello slicing

# %%
a: list[int] = [0,1,2,3,4,5,6,7]
pari = a[0:-1]
print(f"{pari}")

# %% [markdown]
# posso usare anche un passo negativo per partire dalla fine e andare all'inizio degli indici indicati

# %%
a: list[int] = [0,1,2,3,4,5,6,7]
pari = a[::-1]
print(f"{pari}")
# Out:
# [7, 6, 5, 4, 3, 2, 1, 0]

# %% [markdown]
# posso anche non mettere la fine e solo il passo

# %%
a: list[int] = [0,1,2,3,4,5,6,7]
pari = a[0::2]
print(f"{pari}")
# Out:
# [0, 2, 4, 6]

# %% [markdown]
# Liste

# %%
a = [3,1,5]
print (a)

#Modifico il secondo elemento
a[1] = -1
print(a)
# Out:
# [3, 1, 5]
# [3, -1, 5]

# %% [markdown]
# Appendere un valore in fondo alla lista

# %%
a = [1,2,3]
print(a)

#Appendere un valore in fondo alla lista
a.append(4)
print(a)

#Aggiungo un elemento in una posizione specifica
a.insert(1,10)
print(a)
# Out:
# [3, 1, 5]
# [3, 1, 5, 4]
# [3, 10, 1, 5, 4]

# %% [markdown]
# Posso concatenare le lista, ma non fare calcoli aritmetici

# %%
a = ["Ciao", "a"]
b = ["tutti", "come", "va"]
c = a + b
print(c)
#Posso concatenare le lista, ma non fare calcoli aritmetici
# Out:
# ['Ciao', 'a', 'tutti', 'come', 'va']

# %% [markdown]
# Per creare una tupla devo usare comunque la virgola

# %%
a = (3,) #tupla con un solo elemento
#la tupla non può essere modificata

# %% [markdown]
# posso concatenarle come le liste

# %% [markdown]
# Uso le tuple al psto delle liste per una questione di memoria, dato che vengono salvare in maniera migliore delle liste nella memoria, ma anche per un tipo molto utile di assegnazione

# %%
a = (3, "Rosso")

posizione, colore = a
print(f"Posizione: {posizione}, Colore: {colore}")
# Out:
# Posizione: 3, Colore: Rosso

# %% [markdown]
# Puntatori

# %%
#Definisco una lista
a: list[str] = ["Mi", "chiamo", "Luca"]
print(a)

#Assegno una nuova variabile allo stesso oggetto
b = a #ora a e b puntano allo stesso oggetto, quindi b è un puntatore a a
print(b)

#Modifico a
a[-1] = "Davide"
print(a)
print(b)

#O anche
a.append("Evangelista")
print(b)
# Out:
# ['Mi', 'chiamo', 'Luca']
# ['Mi', 'chiamo', 'Luca']
# ['Mi', 'chiamo', 'Davide']
# ['Mi', 'chiamo', 'Davide']
# ['Mi', 'chiamo', 'Davide', 'Evangelista']

# %% [markdown]
# se voglio invcere creare una copia effettiva devo fare nel modo seguente

# %%
# Definisco una lista
a: list[str] = ["Mi", "chiamo", "Luca"]
print(a)

# Assegno una nuova variabile allo stesso oggetto
b = a[:] # Attenzione ai [:].
print(b)

# Modifico a
a[-1] = "Davide"
print(a)
print(b)
# Out:
# ['Mi', 'chiamo', 'Luca']
# ['Mi', 'chiamo', 'Luca']
# ['Mi', 'chiamo', 'Davide']
# ['Mi', 'chiamo', 'Luca']

# %% [markdown]
# Approfondimento 2: Inizializzazione
# La possibilità di aggiungere elementi in una lista, non viene senza conseguenze. Infatti, utilizzando il metodo .append() per aggiungere elementi ad una lista, esegue la seguente serie di steps:
#
# Viene creata una nuova lista, copia della prima, con lunghezza 1 in più della lista di partenza.
#
# L’ultimo elemento della nuova lista corrisponde all’elemento indicato col metodo .append().
#
# La lista iniziale viene eliminata (per opera del garbage collector).
#
# Come risultato, lo spazio in memoria richiesto per allungare una lista data di un elemento è doppio rispetto alla memoria occupata dalla lista stessa. Questo può diventare proibitivo in alcune applicazioni, dove la lista viene allungata varie volte nel giro di un singolo programma.
#
# Per questo motivo, quando ci si aspetta a priori di dover allungare una lista, è buona pratica inizializzare una lista vuota (utilizzando un valore di default, tipo lo 0), i cui elementi verranno sostituiti durante l’esecuzione del programma. Questa fase, chiamata inizializzazione, permette di rendere il codice molto più efficiente in alcuni scenari, come ad esempio quando la lista viene utilizzata per memorizzare alcune informazioni durante le iterazioni di un algoritmo (tipo l’andamento di un’errore).

# %%
# Inizializzo una lista vuota (lunga 4)
a: list[int] = [0] * 4

# %% [markdown]
# Concatenazione multipla

# %%
# Inizializiamo la tupla di output (per salvare memoria)
x = (1, 2, 3, 4, 5)
y = [0] * len(x)
print (y)
# Out:
# [0, 0, 0, 0, 0]

# %% [markdown]
# Posso usare in input una funzione

# %%
def elemento_per_elemento(f, x: tuple[float]) -> list[float]:
    r"""
    Presa in input una funzione f e una tupla di float x, ritorna una lista
    della stessa lunghezza di x, i cui elementi sono gli f(xi).

    Parameters:
    f (function): La funzione da applicare elemento per elemento
    x (tuple): Una tupla di numeri float

    Returns:
    (list): Una tupla contenente gli f(xi)
    """
    # Inizializiamo la tupla di output (per salvare memoria)
    y = [0] * len(x)

    # Cicliamo sugli elementi di x
    for i in range(len(x)):
        xi = x[i] # Estraiamo l'i-esimo elemento di x

        y[i] = f(xi) # Calcoliamo f su xi
    
    return y


def quadrato(x: float) -> float:
    r"""
    Ritorna il quadrato del valore preso in input.

    Parameters:
    x (float): Numero in input

    Returns:
    (float) x^2
    """
    risultato = x**2
    return risultato

def cubo(x: float) -> float:
    r"""
    Ritorna il cubo del valore preso in input.

    Parameters:
    x (float): Numero in input

    Returns:
    (float) x^3
    """
    risultato = x**3
    return risultato

# Esempio
x_vec: tuple[float] = (1, 2, 3, 4, 5)

x_vec_quadrato = elemento_per_elemento(quadrato, x_vec)
x_vec_cubo = elemento_per_elemento(cubo, x_vec)

print(x_vec_quadrato)
print(x_vec_cubo)
# Out:
# [1, 4, 9, 16, 25]
# [1, 8, 27, 64, 125]
